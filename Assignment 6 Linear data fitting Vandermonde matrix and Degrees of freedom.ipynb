# %%
import numpy as np

# Define the range and number of points
start_value = -2
end_value = 2
num_points = 101

# Generate equidistant points
equidistant_points = np.linspace(start_value, end_value, num_points)

# Print the result
print(equidistant_points)
# Out:
# [-2.   -1.96 -1.92 -1.88 -1.84 -1.8  -1.76 -1.72 -1.68 -1.64 -1.6  -1.56
#  -1.52 -1.48 -1.44 -1.4  -1.36 -1.32 -1.28 -1.24 -1.2  -1.16 -1.12 -1.08
#  -1.04 -1.   -0.96 -0.92 -0.88 -0.84 -0.8  -0.76 -0.72 -0.68 -0.64 -0.6
#  -0.56 -0.52 -0.48 -0.44 -0.4  -0.36 -0.32 -0.28 -0.24 -0.2  -0.16 -0.12
#  -0.08 -0.04  0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36
#   0.4   0.44  0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84
#   0.88  0.92  0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32
#   1.36  1.4   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8
#   1.84  1.88  1.92  1.96  2.  ]

# %%
import numpy as np

# Generate equidistant points
t = np.linspace(start_value, end_value, 101)

# Generate normally distributed random variables
mean = 0
std_dev = 5
random_variables = np.random.normal(mean, std_dev, 101)

# Calculate yi = 4t^3 - 4t + random_variable
yi = 4 * t**3 - 4 * t + random_variables

# Print the result
print(yi)
# Out:
# [-26.74144604 -20.91952929 -15.97726612 -15.62557523 -28.38695334
#  -21.45615527  -4.79655438 -17.57884599 -18.50226147 -12.93590918
#   -8.28180805 -14.27289511  -1.22012104 -10.06652913 -17.85504005
#   -6.34075784  -8.63062875   4.5183144    1.31267293 -11.58369911
#    2.7108603    2.36134852 -10.19355584   9.33293758  -5.58182049
#   -3.7007359    0.50485389   2.51942778   5.37166005  10.1575253
#    7.22550819  -1.31521095   3.74009591  -1.57976518   2.33320731
#    5.71099781   3.9599313   -6.94037439   4.73398214  -0.51428915
#    5.41448857  -3.31911718  -1.4965473   -3.54537058   5.56116536
#   -0.79586901  -1.99248765   5.08732372   9.64803513  -0.04310051
#    1.04203896  -7.53453347  -1.91676484   2.25735139  -0.64597827
#    0.94708489  -0.55163815   6.88097768   1.58451631   3.08426886
#   -5.81297657  -0.69986851  -7.43974815  -4.90817052   0.43851011
#   -5.78183368  -0.59451416  -4.54409558   0.44172605   1.70688114
#    1.60155419  -1.72830696  -3.08954724   5.5973321   -5.30653031
#    4.98218525   5.10323363   2.96007657  -7.87597908   1.29473244
#    5.94380809   6.76859124   5.82454538   0.19508275   9.61500558
#   -1.24485732   2.77153157   5.61159421  10.07621111  10.57010168
#    6.85114845   8.61639372  14.67455066  18.09765905   1.27969316
#   19.9884451   18.42193957  21.18446649  15.43581665  17.50731113
#   21.71100615]

# %%
import numpy as np

# Generate equidistant points
t = np.linspace(0, 1, 101)

# Create the Vandermonde matrix
A = np.vander(t, increasing=True)

# Include additional columns for t_i, t_2i, and t_3i
A[:, 1] = t
A[:, 2] = t**2
A[:, 3] = t**3

# Print the result
A = A[:, :4]
A
# Out:
# array([[1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00],
#        [1.00000e+00, 1.00000e-02, 1.00000e-04, 1.00000e-06],
#        [1.00000e+00, 8.50000e-01, 7.22500e-01, 6.14125e-01],
#        [1.00000e+00, 8.60000e-01, 7.39600e-01, 6.36056e-01],
#        [1.00000e+00, 8.70000e-01, 7.56900e-01, 6.58503e-01],
#        [1.00000e+00, 8.80000e-01, 7.74400e-01, 6.81472e-01],
#        [1.00000e+00, 8.90000e-01, 7.92100e-01, 7.04969e-01],
#        [1.00000e+00, 9.00000e-01, 8.10000e-01, 7.29000e-01],
#        [1.00000e+00, 9.10000e-01, 8.28100e-01, 7.53571e-01],
#        [1.00000e+00, 9.20000e-01, 8.46400e-01, 7.78688e-01],
#        [1.00000e+00, 9.30000e-01, 8.64900e-01, 8.04357e-01],
#        [1.00000e+00, 9.40000e-01, 8.83600e-01, 8.30584e-01],
#        [1.00000e+00, 9.50000e-01, 9.02500e-01, 8.57375e-01],
#        [1.00000e+00, 9.60000e-01, 9.21600e-01, 8.84736e-01],
#        [1.00000e+00, 9.70000e-01, 9.40900e-01, 9.12673e-01],
#        [1.00000e+00, 9.80000e-01, 9.60400e-01, 9.41192e-01],
#        [1.00000e+00, 9.90000e-01, 9.80100e-01, 9.70299e-01],
#        [1.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00]])

# %%
import numpy as np

# Assuming A and y are already defined
# If not, generate A using the Vandermonde matrix code from the previous responses
# Also, generate y using the formula 4t^3 - 4t + random_variable

# Solving the least squares problem
x, residuals, rank, singular_values = np.linalg.lstsq(A, yi, rcond=None)

# Print the result
print("Solution vector x:", x)
print("Residuals:", residuals)
print("Rank of the coefficient matrix A:", rank)
print("Singular values of A:", singular_values)
# Out:
# Solution vector x: [ -25.19652282  181.42836319 -384.5073427   250.32559746]
# Residuals: [2375.08545754]
# Rank of the coefficient matrix A: 4
# Singular values of A: [12.32872516  4.1732064   0.83998305  0.10178427]

# %%
import pandas as pd

# %%
df_original = pd.DataFrame({
    'x': equidistant_points,
    'y':yi
})
df_original
# Out:
#         x          y
# 0   -2.00 -26.741446
# 1   -1.96 -20.919529
# 2   -1.92 -15.977266
# 3   -1.88 -15.625575
# 4   -1.84 -28.386953
# ..    ...        ...
# 96   1.84  18.421940
# 97   1.88  21.184466
# 98   1.92  15.435817
# 99   1.96  17.507311
# 100  2.00  21.711006
#
# [101 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(data=df_original, x='x', y='y')
sns.lineplot(x=equidistant_points, y= x[-1] * t**3 + x[-2] * t**2 + x[-3] * t + x[-4], color='r')
plt.title('Equidistant Data Points')
# Out:
# Text(0.5, 1.0, 'Equidistant Data Points')

# %%
AAA = A[:, :2]
AAA
# Out:
# array([[1.  , 0.  ],
#        [1.  , 0.01],
#        [1.  , 0.02],
#        [1.  , 0.03],
#        [1.  , 0.04],
#        [1.  , 0.05],
#        [1.  , 0.06],
#        [1.  , 0.07],
#        [1.  , 0.08],
#        [1.  , 0.09],
#        [1.  , 0.1 ],
#        [1.  , 0.11],
#        [1.  , 0.12],
#        [1.  , 0.13],
#        [1.  , 0.14],
#        [1.  , 0.15],
#        [1.  , 0.16],
#        [1.  , 0.17],
#        [1.  , 0.18],
#        [1.  , 0.19],
#        [1.  , 0.2 ],
#        [1.  , 0.21],
#        [1.  , 0.22],
#        [1.  , 0.23],
#        [1.  , 0.24],
#        [1.  , 0.25],
#        [1.  , 0.26],
#        [1.  , 0.27],
#        [1.  , 0.28],
#        [1.  , 0.29],
#        [1.  , 0.3 ],
#        [1.  , 0.31],
#        [1.  , 0.32],
#        [1.  , 0.33],
#        [1.  , 0.34],
#        [1.  , 0.35],
#        [1.  , 0.36],
#        [1.  , 0.37],
#        [1.  , 0.38],
#        [1.  , 0.39],
#        [1.  , 0.4 ],
#        [1.  , 0.41],
#        [1.  , 0.42],
#        [1.  , 0.43],
#        [1.  , 0.44],
#        [1.  , 0.45],
#        [1.  , 0.46],
#        [1.  , 0.47],
#        [1.  , 0.48],
#        [1.  , 0.49],
#        [1.  , 0.5 ],
#        [1.  , 0.51],
#        [1.  , 0.52],
#        [1.  , 0.53],
#        [1.  , 0.54],
#        [1.  , 0.55],
#        [1.  , 0.56],
#        [1.  , 0.57],
#        [1.  , 0.58],
#        [1.  , 0.59],
#        [1.  , 0.6 ],
#        [1.  , 0.61],
#        [1.  , 0.62],
#        [1.  , 0.63],
#        [1.  , 0.64],
#        [1.  , 0.65],
#        [1.  , 0.66],
#        [1.  , 0.67],
#        [1.  , 0.68],
#        [1.  , 0.69],
#        [1.  , 0.7 ],
#        [1.  , 0.71],
#        [1.  , 0.72],
#        [1.  , 0.73],
#        [1.  , 0.74],
#        [1.  , 0.75],
#        [1.  , 0.76],
#        [1.  , 0.77],
#        [1.  , 0.78],
#        [1.  , 0.79],
#        [1.  , 0.8 ],
#        [1.  , 0.81],
#        [1.  , 0.82],
#        [1.  , 0.83],
#        [1.  , 0.84],
#        [1.  , 0.85],
#        [1.  , 0.86],
#        [1.  , 0.87],
#        [1.  , 0.88],
#        [1.  , 0.89],
#        [1.  , 0.9 ],
#        [1.  , 0.91],
#        [1.  , 0.92],
#        [1.  , 0.93],
#        [1.  , 0.94],
#        [1.  , 0.95],
#        [1.  , 0.96],
#        [1.  , 0.97],
#        [1.  , 0.98],
#        [1.  , 0.99],
#        [1.  , 1.  ]])

# %%
AA = A[:, :3]
AA
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00],
#        [1.000e+00, 1.000e-02, 1.000e-04],
#        [1.000e+00, 2.000e-02, 4.000e-04],
#        [1.000e+00, 3.000e-02, 9.000e-04],
#        [1.000e+00, 4.000e-02, 1.600e-03],
#        [1.000e+00, 5.000e-02, 2.500e-03],
#        [1.000e+00, 6.000e-02, 3.600e-03],
#        [1.000e+00, 7.000e-02, 4.900e-03],
#        [1.000e+00, 8.000e-02, 6.400e-03],
#        [1.000e+00, 9.000e-02, 8.100e-03],
#        [1.000e+00, 1.000e-01, 1.000e-02],
#        [1.000e+00, 1.100e-01, 1.210e-02],
#        [1.000e+00, 1.200e-01, 1.440e-02],
#        [1.000e+00, 1.300e-01, 1.690e-02],
#        [1.000e+00, 1.400e-01, 1.960e-02],
#        [1.000e+00, 1.500e-01, 2.250e-02],
#        [1.000e+00, 1.600e-01, 2.560e-02],
#        [1.000e+00, 1.700e-01, 2.890e-02],
#        [1.000e+00, 1.800e-01, 3.240e-02],
#        [1.000e+00, 1.900e-01, 3.610e-02],
#        [1.000e+00, 2.000e-01, 4.000e-02],
#        [1.000e+00, 2.100e-01, 4.410e-02],
#        [1.000e+00, 2.200e-01, 4.840e-02],
#        [1.000e+00, 2.300e-01, 5.290e-02],
#        [1.000e+00, 2.400e-01, 5.760e-02],
#        [1.000e+00, 2.500e-01, 6.250e-02],
#        [1.000e+00, 2.600e-01, 6.760e-02],
#        [1.000e+00, 2.700e-01, 7.290e-02],
#        [1.000e+00, 2.800e-01, 7.840e-02],
#        [1.000e+00, 2.900e-01, 8.410e-02],
#        [1.000e+00, 3.000e-01, 9.000e-02],
#        [1.000e+00, 3.100e-01, 9.610e-02],
#        [1.000e+00, 3.200e-01, 1.024e-01],
#        [1.000e+00, 3.300e-01, 1.089e-01],
#        [1.000e+00, 3.400e-01, 1.156e-01],
#        [1.000e+00, 3.500e-01, 1.225e-01],
#        [1.000e+00, 3.600e-01, 1.296e-01],
#        [1.000e+00, 3.700e-01, 1.369e-01],
#        [1.000e+00, 3.800e-01, 1.444e-01],
#        [1.000e+00, 3.900e-01, 1.521e-01],
#        [1.000e+00, 4.000e-01, 1.600e-01],
#        [1.000e+00, 4.100e-01, 1.681e-01],
#        [1.000e+00, 4.200e-01, 1.764e-01],
#        [1.000e+00, 4.300e-01, 1.849e-01],
#        [1.000e+00, 4.400e-01, 1.936e-01],
#        [1.000e+00, 4.500e-01, 2.025e-01],
#        [1.000e+00, 4.600e-01, 2.116e-01],
#        [1.000e+00, 4.700e-01, 2.209e-01],
#        [1.000e+00, 4.800e-01, 2.304e-01],
#        [1.000e+00, 4.900e-01, 2.401e-01],
#        [1.000e+00, 5.000e-01, 2.500e-01],
#        [1.000e+00, 5.100e-01, 2.601e-01],
#        [1.000e+00, 5.200e-01, 2.704e-01],
#        [1.000e+00, 5.300e-01, 2.809e-01],
#        [1.000e+00, 5.400e-01, 2.916e-01],
#        [1.000e+00, 5.500e-01, 3.025e-01],
#        [1.000e+00, 5.600e-01, 3.136e-01],
#        [1.000e+00, 5.700e-01, 3.249e-01],
#        [1.000e+00, 5.800e-01, 3.364e-01],
#        [1.000e+00, 5.900e-01, 3.481e-01],
#        [1.000e+00, 6.000e-01, 3.600e-01],
#        [1.000e+00, 6.100e-01, 3.721e-01],
#        [1.000e+00, 6.200e-01, 3.844e-01],
#        [1.000e+00, 6.300e-01, 3.969e-01],
#        [1.000e+00, 6.400e-01, 4.096e-01],
#        [1.000e+00, 6.500e-01, 4.225e-01],
#        [1.000e+00, 6.600e-01, 4.356e-01],
#        [1.000e+00, 6.700e-01, 4.489e-01],
#        [1.000e+00, 6.800e-01, 4.624e-01],
#        [1.000e+00, 6.900e-01, 4.761e-01],
#        [1.000e+00, 7.000e-01, 4.900e-01],
#        [1.000e+00, 7.100e-01, 5.041e-01],
#        [1.000e+00, 7.200e-01, 5.184e-01],
#        [1.000e+00, 7.300e-01, 5.329e-01],
#        [1.000e+00, 7.400e-01, 5.476e-01],
#        [1.000e+00, 7.500e-01, 5.625e-01],
#        [1.000e+00, 7.600e-01, 5.776e-01],
#        [1.000e+00, 7.700e-01, 5.929e-01],
#        [1.000e+00, 7.800e-01, 6.084e-01],
#        [1.000e+00, 7.900e-01, 6.241e-01],
#        [1.000e+00, 8.000e-01, 6.400e-01],
#        [1.000e+00, 8.100e-01, 6.561e-01],
#        [1.000e+00, 8.200e-01, 6.724e-01],
#        [1.000e+00, 8.300e-01, 6.889e-01],
#        [1.000e+00, 8.400e-01, 7.056e-01],
#        [1.000e+00, 8.500e-01, 7.225e-01],
#        [1.000e+00, 8.600e-01, 7.396e-01],
#        [1.000e+00, 8.700e-01, 7.569e-01],
#        [1.000e+00, 8.800e-01, 7.744e-01],
#        [1.000e+00, 8.900e-01, 7.921e-01],
#        [1.000e+00, 9.000e-01, 8.100e-01],
#        [1.000e+00, 9.100e-01, 8.281e-01],
#        [1.000e+00, 9.200e-01, 8.464e-01],
#        [1.000e+00, 9.300e-01, 8.649e-01],
#        [1.000e+00, 9.400e-01, 8.836e-01],
#        [1.000e+00, 9.500e-01, 9.025e-01],
#        [1.000e+00, 9.600e-01, 9.216e-01],
#        [1.000e+00, 9.700e-01, 9.409e-01],
#        [1.000e+00, 9.800e-01, 9.604e-01],
#        [1.000e+00, 9.900e-01, 9.801e-01],
#        [1.000e+00, 1.000e+00, 1.000e+00]])

# %%
# Solving the least squares problem
xx, residuals, rank, singular_values = np.linalg.lstsq(AA, yi, rcond=None)
xxx, residuals, rank, singular_values = np.linalg.lstsq(AAA, yi, rcond=None)

# Print the result
print("Solution vector x:", xx)
print("Residuals:", residuals)
print("Rank of the coefficient matrix A:", rank)
print("Singular values of A:", singular_values)
# Out:
# Solution vector x: [-13.05322809  31.97897499  -9.0189465 ]
# Residuals: [4818.66211411]
# Rank of the coefficient matrix A: 2
# Singular values of A: [11.31654981  2.60205695]

# %%
plt.figure(figsize=(9, 9))
sns.scatterplot(data=df_original, x='x', y='y')
sns.lineplot(x=equidistant_points, y= x[-1] * t**3 + x[-2] * t**2 + x[-3] * t + x[-4], color='r', label='Cubic Polynomial')
sns.lineplot(x=equidistant_points, y= xx[-1] * t**2 + xx[-2] * t + xx[-3], color='g', label='Quadratic Polynomial')
sns.lineplot(x=equidistant_points, y= xxx[-1] * t + xxx[-2], color='orange', label='Linear Polynomial')
plt.title('Equidistant Data Points')
# Out:
# Text(0.5, 1.0, 'Equidistant Data Points')

# %%
# Calculate Mean Squared Error
from sklearn.metrics import r2_score
mse = np.mean((yi - (x[-1] * t**3 + x[-2] * t**2 + x[-3] * t + x[-4]))**2)
mse2 = np.mean((yi - (xx[-1] * t**2 + xx[-2] * t + xx[-3]))**2)
mse3 = np.mean((yi - (xxx[-1] * t + xxx[-2]))**2)
r_squared = r2_score(yi, (x[-1] * t**3 + x[-2] * t**2 + x[-3] * t + x[-4]))
r_squared2 = r2_score(yi, (xx[-1] * t**2 + xx[-2] * t + xx[-3]))
r_squared3 = r2_score(yi, (xxx[-1] * t + xxx[-2]))

print("Mean Squared Error of Cubic fitting:", mse)
print("R-squared of Cubic fitting:", r_squared)
print("Mean Squared Error of Quadratic fitting:", mse2)
print("R-squared of Quadratic fitting:", r_squared2)
print("Mean Squared Error of Linear fitting:", mse3)
print("R-squared of Linear fitting:", r_squared3)
# Out:
# Mean Squared Error of Cubic fitting: 23.51569759943039
# R-squared of Cubic fitting: 0.74582672806822
# Mean Squared Error of Quadratic fitting: 47.23951089397447
# R-squared of Quadratic fitting: 0.48940400353382263
# Mean Squared Error of Linear fitting: 47.70952588228448
# R-squared of Linear fitting: 0.48432376949310985
